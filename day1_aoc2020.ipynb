# %% [markdown]
# # Day 1: Report Repair
# https://adventofcode.com/2020/day/1

# %%
import pandas as pd
from numpy import loadtxt

# %%
# expense_report = [1721, 979, 366, 299, 675, 1456]
# expense_report
    
expense_report = loadtxt("aoc_day1_data.csv")
expense_report = expense_report.tolist()
expense_report
# Out:
# [1977.0,
#  1515.0,
#  1857.0,
#  1800.0,
#  1737.0,
#  1778.0,
#  1505.0,
#  1958.0,
#  1982.0,
#  1941.0,
#  1417.0,
#  1232.0,
#  1234.0,
#  2005.0,
#  1637.0,
#  1956.0,
#  1252.0,
#  1457.0,
#  1494.0,
#  1317.0,
#  1388.0,
#  1630.0,
#  1207.0,
#  1536.0,
#  1225.0,
#  1369.0,
#  1343.0,
#  1502.0,
#  1616.0,
#  1744.0,
#  1950.0,
#  1280.0,
#  1647.0,
#  1780.0,
#  1435.0,
#  1915.0,
#  1365.0,
#  1707.0,
#  1795.0,
#  1554.0,
#  1652.0,
#  539.0,
#  1892.0,
#  1546.0,
#  1908.0,
#  1629.0,
#  1836.0,
#  1805.0,
#  1395.0,
#  1360.0,
#  1487.0,
#  1739.0,
#  1884.0,
#  1427.0,
#  1615.0,
#  1470.0,
#  1922.0,
#  1753.0,
#  1632.0,
#  1968.0,
#  1429.0,
#  2008.0,
#  1124.0,
#  1441.0,
#  1384.0,
#  1955.0,
#  1815.0,
#  1741.0,
#  1331.0,
#  1442.0,
#  1988.0,
#  1788.0,
#  1585.0,
#  1794.0,
#  1217.0,
#  1434.0,
#  1751.0,
#  1240.0,
#  1284.0,
#  1883.0,
#  1711.0,
#  1376.0,
#  1638.0,
#  1932.0,
#  1979.0,
#  1769.0,
#  1597.0,
#  896.0,
#  1691.0,
#  1379.0,
#  1386.0,
# ...

# %%
#2 and 3 numbers
possible_amounts = []
for amount in expense_report:
    possible_amounts.append(2020 - amount)
    print(2020 - amount)
possible_amounts
# Out:
# 43.0
# 505.0
# 163.0
# 220.0
# 283.0
# 242.0
# 515.0
# 62.0
# 38.0
# 79.0
# 603.0
# 788.0
# 786.0
# 15.0
# 383.0
# 64.0
# 768.0
# 563.0
# 526.0
# 703.0
# 632.0
# 390.0
# 813.0
# 484.0
# 795.0
# 651.0
# 677.0
# 518.0
# 404.0
# 276.0
# 70.0
# 740.0
# 373.0
# 240.0
# 585.0
# 105.0
# 655.0
# 313.0
# 225.0
# 466.0
# 368.0
# 1481.0
# 128.0
# 474.0
# 112.0
# 391.0
# 184.0
# 215.0
# 625.0
# 660.0
# 533.0
# 281.0
# 136.0
# 593.0
# 405.0
# 550.0
# 98.0
# 267.0
# 388.0
# 52.0
# 591.0
# 12.0
# 896.0
# 579.0
# 636.0
# 65.0
# 205.0
# 279.0
# 689.0
# 578.0
# 32.0
# 232.0
# 435.0
# 226.0
# 803.0
# 586.0
# 269.0
# 780.0
# 736.0
# 137.0
# 309.0
# 644.0
# 382.0
# 88.0
# 41.0
# 251.0
# 423.0
# 1124.0
# 329.0
# 641.0
# 634.0
# 362.0
# 11.0
# 135.0
# 299.0
# 401.0
# 195.0
# 332.0
# 476.0
# 86.0
# 536.0
# 300.0
# 805.0
# 649.0
# 268.0
# 328.0
# 275.0
# 109.0
# 567.0
# 297.0
# 164.0
# 750.0
# 623.0
# 1208.0
# 410.0
# 308.0
# 191.0
# 496.0
# 479.0
# 682.0
# 637.0
# 428.0
# 14.0
# 197.0
# 610.0
# 598.0
# ...

# %%
# 3 numbers
possible_amounts_2 = []
for amount in possible_amounts:
    for amount2 in expense_report:
        possible_amounts_2.append(amount - amount2)
possible_amounts_2
# Out:
# [-1934.0,
#  -1472.0,
#  -1814.0,
#  -1757.0,
#  -1694.0,
#  -1735.0,
#  -1462.0,
#  -1915.0,
#  -1939.0,
#  -1898.0,
#  -1374.0,
#  -1189.0,
#  -1191.0,
#  -1962.0,
#  -1594.0,
#  -1913.0,
#  -1209.0,
#  -1414.0,
#  -1451.0,
#  -1274.0,
#  -1345.0,
#  -1587.0,
#  -1164.0,
#  -1493.0,
#  -1182.0,
#  -1326.0,
#  -1300.0,
#  -1459.0,
#  -1573.0,
#  -1701.0,
#  -1907.0,
#  -1237.0,
#  -1604.0,
#  -1737.0,
#  -1392.0,
#  -1872.0,
#  -1322.0,
#  -1664.0,
#  -1752.0,
#  -1511.0,
#  -1609.0,
#  -496.0,
#  -1849.0,
#  -1503.0,
#  -1865.0,
#  -1586.0,
#  -1793.0,
#  -1762.0,
#  -1352.0,
#  -1317.0,
#  -1444.0,
#  -1696.0,
#  -1841.0,
#  -1384.0,
#  -1572.0,
#  -1427.0,
#  -1879.0,
#  -1710.0,
#  -1589.0,
#  -1925.0,
#  -1386.0,
#  -1965.0,
#  -1081.0,
#  -1398.0,
#  -1341.0,
#  -1912.0,
#  -1772.0,
#  -1698.0,
#  -1288.0,
#  -1399.0,
#  -1945.0,
#  -1745.0,
#  -1542.0,
#  -1751.0,
#  -1174.0,
#  -1391.0,
#  -1708.0,
#  -1197.0,
#  -1241.0,
#  -1840.0,
#  -1668.0,
#  -1333.0,
#  -1595.0,
# ...

# %%
# 3 numbers
res = [key for key, val in enumerate(expense_report) 
                      if val in set(possible_amounts_2)] 
res
expense_report[res[0]]*expense_report[res[1]]*expense_report[res[2]]
# Out:
# 18847752.0

# %%
# 2 numbers
res = [key for key, val in enumerate(expense_report) 
                      if val in set(possible_amounts)] 
expense_report[res[0]]*expense_report[res[1]]
# Out:
# [62, 87]

# %%
# Out:
# 1007104.0
